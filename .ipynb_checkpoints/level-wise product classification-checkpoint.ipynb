# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from string import digits
from nltk.tokenize import RegexpTokenizer
from keras.preprocessing.text import Tokenizer
from nltk.corpus import stopwords
import nltk
# nltk.download('words')

# %%
token = RegexpTokenizer("[\w']+")
sw = stopwords.words('english')
words = set(nltk.corpus.words.words())
# sw

# %%
def get_datasets(): 
    columnLabels = ['country', 'id', 'title', 'c1', 'c2', 'c3', 'description', 'price', 'type']
    train = pd.read_csv("data_train.csv", names=columnLabels, encoding = 'utf16')
    test = pd.read_csv("data_test.csv", names=columnLabels)
#     train.column = test.column = columnLabels
    return train, test

# %%
def preprocess_twoCol(dataframe):
    
    df = pd.DataFrame()
    #tokenize and convert to lower case
    dataframe['title'] = dataframe['title'].apply(lambda x: token.tokenize(x.lower()))
    #stopword removal
    dataframe['title'] = dataframe['title'].apply(lambda x: ' '.join([w for w in x if w not in sw]))
    #remove punctuations and other symbols
    dataframe['title'] = dataframe['title'].apply(lambda x: [w for w in nltk.wordpunct_tokenize(x)\
                                                             if w is not w.isalpha() and not w.isnumeric()])
    #remove digits
    dataframe['title'] = dataframe['title'].apply(lambda x: [w.translate({ord(k): None for k in digits}) for w in x])
    #remove single length words
    dataframe['title'] = dataframe['title'].apply(lambda x: ' '.join([w for w in x if len(w)>1]))
    
    df['title'] = dataframe['title'].values
    df['c1'] = dataframe['c1'].values
    
    maxlen = df.title.map(lambda x: len(token.tokenize(x))).max() # find length of longest product title (with max words)
    print(maxlen)
 
    return df


def get_categories():  
    return

# %%
train_df, test_df = get_datasets()
tCol_df = preprocess_twoCol(train_df)
print(train_df.c1.value_counts().plot(kind='bar', title='TrainCount(c1)'))
# Out:
# 39
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
tCol_df
# Out:
#                                                    title  \
# 0             adana gallery suri square hijab light pink
# 1            cuba heartbreaker eau de parfum spray ml oz
# 2      andoer cm cellphone smartphone mini dual heade...
# 3      anmyna complaint silky set ºæ shampoo ml condi...
# 4              argital argiltubo green clay face body ml
# ...                                                  ...
# 36278  sades led backlit wired usb mechanical gaming ...
# 36279                             sona electric oven seo
# 36280  op portable wireless bluetooth speaker hands f...
# 36281              woot woot tictactoe pillow case white
# 36282  new smart wristband smart bracelet heart rate ...
#
#                                           c1
# 0                                    Fashion
# 1                            Health & Beauty
# 2      TV, Audio / Video, Gaming & Wearables
# 3                            Health & Beauty
# 4                            Health & Beauty
# ...                                      ...
# 36278                    Computers & Laptops
# 36279                        Home Appliances
# 36280                    Computers & Laptops
# 36281                          Home & Living
# 36282  TV, Audio / Video, Gaming & Wearables
#
# [36283 rows x 2 columns]

# %%
maxWords = 5000
MaxWordLength = tCol_df.title.map(lambda x: len(token.tokenize(x))).max()
embeddingDimensions = 100
tokenizer = Tokenizer(num_words = maxWords, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(tCol_df['title'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 23414 unique tokens.

# %%
word_index.keys()
# Out:
# dict_keys(['black', 'intl', 'case', 'women', 'cover', 'white', 'watch', 'leather', 'fashion', 'men', 'usb', 'blue', 'phone', 'samsung', 'iphone', 'export', 'new', 'mini', 'set', 'red', 'gb', 'galaxy', 'gold', 'silver', 'bag', 'ml', 'camera', 'mm', 'led', 'amp', 'plus', 'cable', 'back', 'pcs', 'color', 'pink', 'casual', 'steel', 'apple', 'pc', 'light', 'green', 'card', 'multicolor', 'free', 'pu', 'charger', 'holder', 'hard', 'adapter', 'long', 'high', 'stainless', 'flip', 'tpu', 'bluetooth', 'wireless', 'wallet', 'soft', 'wall', 'dress', 'screen', 'stand', 'waterproof', 'slim', 'strap', 'quartz', 'inch', 'home', 'shoes', 'glass', 'portable', 'hd', 'laptop', 'shirt', 'size', 'digital', 'sleeve', 'power', 'car', 'smart', 'cm', 'protector', 'brown', 'hair', 'protective', 'style', 'silicone', 'pattern', 'plastic', 'battery', 'drive', 'box', 'metal', 'sony', 'ultra', 'bracelet', 'rose', 'micro', 'design', 'sports', 'note', 'crystal', 'dual', 'band', 'necklace', 'wrist', 'purple', 'sexy', 'storage', 'body', 'full', 'mobile', 'quality', 'flower', 'oz', 'flash', 'yellow', 'xiaomi', 'short', 'air', 'pro', 'shoulder', 'grey', 'ipad', 'cotton', 'neck', 'sport', 'clear', 'ring', 'ladies', 'tempered', 'huawei', 'anti', 'android', 'luxury', 'jewelry', 'frame', 'data', 'skin', 'glasses', 'lens', 'hot', 'hp', 'watches', 'tool', 'male', 'one', 'art', 'water', 'lcd', 'round', 'diy', 'kit', 'stick', 'replacement', 'lace', 'vintage', 'brand', 'summer', 'earrings', 'party', 'sunglasses', 'charging', 'decor', 'mp', 'tv', 'mount', 'belt', 'universal', 'pen', 'ac', 'mens', 'lg', 'memory', 'plated', 'lady', 'headset', 'series', 'thin', 'gift', 'asus', 'kitchen', 'lenovo', 'wedding', 'wifi', 'touch', 'lamp', 'ear', 'female', 'purse', 'speaker', 'video', 'outdoor', 'display', 'print', 'brush', 'diamond', 'multi', 'pendant', 'stereo', 'electric', 'double', 'magnetic', 'top', 'unisex', 'coffee', 'original', 'retro', 'plug', 'rhinestone', 'hand', 'shell', 'chain', 'genuine', 'korean', 'xperia', 'hybrid', 'canvas', 'orange', 'table', 'sticker', 'mah', 'travel', 'gel', 'bags', 'type', 'cream', 'edge', 'se', 'analog', 'clock', 'premium', 'business', 'tablet', 'dark', 'cord', 'super', 'solid', 'disk', 'oil', 'remote', 'professional', 'heart', 'waist', 'machine', 'flat', 'makeup', 'decoration', 'pack', 'gopro', 'classic', 'aluminum', 'control', 'htc', 'clip', 'core', 'handbag', 'hero', 'armor', 'cartoon', 'dial', 'large', 'tops', 'keyboard', 'rubber', 'painting', 'piece', 'pants', 'shockproof', 'cute', 'head', 'night', 'transparent', 'monitor', 'kids', 'hdmi', 'floral', 'cap', 'pin', 'earphone', 'macbook', 'nail', 'headphone', 'mouse', 'backpack', 'mirror', 'de', 'accessories', 'room', 'adjustable', 'winter', 'support', 'warm', 'single', 'small', 'port', 'elegant', 'alloy', 'dvr', 'mi', 'rack', 'printed', 'slip', 'cup', 'womens', 'pouch', 'non', 'fit', 'stickers', 'loose', 'beach', 'canon', 'girls', 'wristwatch', 'gaming', 'automatic', 'sd', 'sleeveless', 'shape', 'audio', 'spy', 'face', 'girl', 'action', 'sync', 'xl', 'door', 'bottle', 'moonmini', 'chiffon', 'electronic', 'desktop', 'beige', 'gray', 'square', 'window', 'key', 'uv', 'monopod', 'colorful', 'pocket', 'love', 'clutch', 'paper', 'plate', 'fan', 'handle', 'eye', 'spray', 'film', 'mat', 'dv', 'butterfly', 'mic', 'acer', 'big', 'slot', 'cross', 'care', 'function', 'casio', 'shirts', 'tools', 'eau', 'printing', 'filter', 'shock', 'hat', 'ps', 'layer', 'blouse', 'otg', 'organizer', 'creative', 'man', 'smartphone', 'sun', 'cell', 'zipper', 'iron', 'pure', 'hidden', 'tf', 'player', 'speed', 'rechargeable', 'redmi', 'coat', 'cat', 'optical', 'natural', 'tb', 'jacket', 'tote', 'photo', 'bumper', 'stylish', 'buildphone', 'underwear', 'simple', 'charge', 'controller', 'bank', 'cam', 'heavy', 'microphone', 'mask', 'foldable', 'sj', 'oppo', 'protection', 'buy', 'colors', 'alarm', 'panel', 'clothes', 'pavilion', 'line', 'matte', 'cosmetic', 'folding', 'tab', 'zenfone', 'pad', 'autumn', 'beauty', 'fast', 'hollow', ...

# %%
# print(test_df.c1.value_counts().plot(kind='bar', title='TestCount(c1)'))
